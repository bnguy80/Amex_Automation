# %%
import xlwings as xw
import pandas as pd
import numpy as np
import re
from itertools import combinations

workbook_path = 'G:/B_Amex/Template.xlsm'
wb = xw.Book(workbook_path)
ws = wb.sheets['File Name']
ws1 = wb.sheets['Transaction Details 2']

def load_dataframe(worksheet, header_row=7):
    # Use 'A' + str(header_row) if your data starts from column A
    data_range = worksheet.range('A' + str(header_row)).expand('table')

    # Convert the data range to a DataFrame. By default, the header is taken from the first row of the range
    df = data_range.options(pd.DataFrame, index=False, header=True).value

    # If the headers are not properly captured, you might need to adjust the header argument
    return df

df_file_name = load_dataframe(ws)
df_transaction_details = load_dataframe(ws1)

# %%
def convert_dates(df, date_column):
    # Replace "Date Not Found" or any non-standard date strings with np.nan
    df[date_column] = df[date_column].astype(str).apply(
        lambda x: x if re.match(r'^\d{4}-\d{2}-\d{2}', x) else np.nan)

    # Now convert the cleaned date strings to datetime, errors='coerce' will handle any remaining non-date strings by converting them to NaT
    df[date_column] = pd.to_datetime(df[date_column], errors='coerce')

    return df

df_transaction_details = convert_dates(df_transaction_details, 'Date')
df_file_name = convert_dates(df_file_name, 'Date')

# %%
df_file_name
# Out:
#                                             File Name  \
# 0       Comcast_Business_Internet_Invoice_1766273.pdf
# 1   Dell_Monitors_US_ORDERACK_f000c1d1-cf7f-49d4-a...
# 2   Dell_Monitors_US_ORDERACK_f000c1d1-cf7f-49d4-a...
# 3                        Adobe Acrobat for Lauren.pdf
# 4                           Server supply 4183063.pdf
# 5            Apple_MacBook_Airs_AAA1533245 - Copy.pdf
# 6                   Apple_MacBook_Airs_AAA1533245.pdf
# 7                   Apple_MacBook_Pros_AAA1533249.pdf
# 8   MSFT Project Plan 3 (Nonprofit Staff Pricing).pdf
# 9    MSFT Office 365 E3 (Nonprofit Staff Pricing).pdf
# 10                            Amazon_Webcam_AnnaS.pdf
# 11                             Amazon_Webcam_Tony.pdf
# 12             Granite_1312024_03354959_635226634.pdf
# 13  MSFT Project Online Essentials (Nonprofit Staf...
# 14                       LastPass_Renewal_Receipt.pdf
# 15  calendly-billing_invoice_AzqVbSU5PZzivLBTV - C...
# 16                            Amazon_Monitor_Tony.pdf
# 17                          Adobe for Stacy Bogle.pdf
# 18                            Amazon_Batteries_IT.pdf
# 19                         Comcast_Business_Cable.pdf
# 20                       Amazon_Speakerphone_Anna.pdf
# 21     calendly-billing_invoice_AzqVbSU5PZzivLBTV.pdf
# 22            Amazon_Bluetooth_Speakers_IT_Events.pdf
# 23           Amazon_Shipping_Materials_Chicago_DR.pdf
# 24                       ChatGPT_Business_Plan_IT.pdf
# 25               Adobe Acrobat for Morgan Johnson.pdf
# 26                   Cloudflare_Feb_for_Marketing.pdf
# 27                       Cloudflare_Feb_for_Comms.pdf
# 28                   NewRelic_Invoice_INV00972418.pdf
# 29        ServerCentral_Deft_transaction-IN136900.pdf
# 30               Adobe Acrobat for Lauren Another.pdf
# 26  G:\t3nas\APPS\[02] Feb 2024\Cloudflare_Feb_for...   250.00  CLOUDFLARE
# 27  G:\t3nas\APPS\[02] Feb 2024\Cloudflare_Feb_for...   250.00  CLOUDFLARE
# 28  G:\t3nas\APPS\[02] Feb 2024\NewRelic_Invoice_I...    75.00         NEW
# 29  G:\t3nas\APPS\[02] Feb 2024\ServerCentral_Deft...  1896.26      SERVER
# 30  G:\t3nas\APPS\[02] Feb 2024\Adobe Acrobat for ...    13.77       ADOBE
# 31  G:\t3nas\APPS\[02] Feb 2024\CompTIA Server+ Bu...  1132.00     COMPTIA
# 32  G:\t3nas\APPS\[02] Feb 2024\1ft 2ft Cat6a cabl...    25.18      AMAZON
# 33  G:\t3nas\APPS\[02] Feb 2024\Amazon_Networking_...    24.98      AMAZON
# 34        G:\t3nas\APPS\[02] Feb 2024\CBT_Nuggets.pdf   187.62         CBT
# 35  G:\t3nas\APPS\[02] Feb 2024\Amazon_ESTATA_Data...    14.84      AMAZON
# 36  G:\t3nas\APPS\[02] Feb 2024\MSFT Microsoft Def...   144.00        MSFT
#
#          Date
# 0  2024-02-14
# 1  2024-02-14
# 2  2024-02-14
# 3  2024-02-14
# 4  2024-02-08
# 5  2024-02-13
# 6  2024-02-13
# 7  2024-02-13
# 8  2024-02-12
# 9  2024-02-12
# 10 2024-02-07
# 11 2024-02-07
# 12 2024-02-01
# 13 2024-02-12
# 14 2024-02-12
# 15 2024-02-08
# 16 2024-02-05
# 17 2024-01-31
# 18 2024-01-30
# 19 2024-01-26
# 20 2024-02-07
# 21 2024-02-08
# 22 2024-01-25
# 23 2024-02-06
# 24 2024-02-06
# 25 2024-01-24
# 26 2024-02-03
# 27 2024-02-03
# 28 2024-01-31
# 29 2024-02-02
# 30 2024-01-30
# 31        NaT
# 32 2024-01-23
# 33 2024-01-23
# 34 2024-02-21
# 35 2024-02-14
# 36 2024-02-12

# %%
def find_matching_transactions(row, df_transaction_details, matched_transactions):
    vendor = row['Vendor']
    total = row['Amount']  # Assuming this column exists in df_file_name and represents the invoice total
    invoice_date = row['Date']  # Assuming 'Date' is already a datetime object
    file_name = row['File Name']

    # Filter transactions by the same vendor, date, and which have not been matched yet
    transactions = df_transaction_details[
        (df_transaction_details['Vendor'].str.contains(vendor, case=False, na=False)) &
        (df_transaction_details['Date'] == invoice_date) &
        (~df_transaction_details.index.isin(matched_transactions))
        ]

    # Strategy 1: Direct match between invoice total and transaction amount, matching dates
    direct_matches = transactions[transactions['Amount'] == total]
    if not direct_matches.empty:
        first_direct_match = direct_matches.index[0]  # get index of first direct match
        matched_transactions.update([first_direct_match])
        df_transaction_details.loc[first_direct_match, 'File name'] = file_name
        return
    
    # Strategy 2: Direct match between invoice total and transaction amount, excluding transactions with matching dates
    direct_matches_non_matching_date = df_transaction_details[
        (df_transaction_details['Vendor'].str.contains(vendor, case=False, na=False)) &
        (df_transaction_details['Amount'] == total) &
        (df_transaction_details['Date'] != invoice_date) &  # Exclude transactions with matching dates
        (~df_transaction_details.index.isin(matched_transactions))
    ]
    
    if not direct_matches_non_matching_date.empty:
        first_direct_match = direct_matches_non_matching_date.index[0]  # get index of first direct match
        matched_transactions.update([first_direct_match])
        df_transaction_details.loc[first_direct_match, 'Column1'] = 'Check Date'
        df_transaction_details.loc[first_direct_match, 'File name'] = file_name
        return

    # If no conditions are met, you might want to flag this for manual review
    print(f"No match found for {file_name} with Amount {total}")


matched_transactions = set()

# Iterate over the file name DataFrame and find matching transactions
df_transaction_details_copy = df_transaction_details.copy()
for index, row in df_file_name.iterrows():
    find_matching_transactions(row, df_transaction_details_copy, matched_transactions)

df_transaction_details_copy
# Out:
# No match found for Dell_Monitors_US_ORDERACK_f000c1d1-cf7f-49d4-ab05-11878fffa8f1 - Copy.pdf with Amount 723.58
# No match found for Dell_Monitors_US_ORDERACK_f000c1d1-cf7f-49d4-ab05-11878fffa8f1.pdf with Amount 723.58
# No match found for Apple_MacBook_Airs_AAA1533245 - Copy.pdf with Amount 4704.0
# No match found for Apple_MacBook_Airs_AAA1533245.pdf with Amount 4704.0
# No match found for Granite_1312024_03354959_635226634.pdf with Amount 43.25
# No match found for calendly-billing_invoice_AzqVbSU5PZzivLBTV - Copy.pdf with Amount 864.0
# No match found for calendly-billing_invoice_AzqVbSU5PZzivLBTV.pdf with Amount 864.0
# No match found for Cloudflare_Feb_for_Marketing.pdf with Amount 250.0
# No match found for Cloudflare_Feb_for_Comms.pdf with Amount 250.0
#          Date Receipt                                 Description   Amount  \
# 0  2024-02-16    None  COMCAST BUSINESS    PHILADELPHIA        PA  1489.95
# 1  2024-02-15    None  DELL INC            ROUND ROCK          TX   321.59
# 2  2024-02-15    None  DELL INC            ROUND ROCK          TX   401.99
# 3  2024-02-14    None  ADOBE SYSTEMS Adobe SAN JOSE            CA    27.54
# 4  2024-02-14    None                     AMAZON MARKEPLACE NA PA    14.84
# 5  2024-02-13    None  APPLE ONLINE STORE  CUPERTINO           CA  1568.00
# 6  2024-02-13    None  APPLE ONLINE STORE  CUPERTINO           CA  3136.00
# 7  2024-02-13    None  APPLE ONLINE STORE  CUPERTINO           CA  3672.00
# 8  2024-02-13    None             MSFT *<E0500QZD1L>  MSBILL.INFO   144.00
# 9  2024-02-13    None             MSFT *<E0500QZD1M>  MSBILL.INFO    24.00
# 10 2024-02-13    None             MSFT *<E0500QZLZW>  MSBILL.INFO  1443.25
# 11 2024-02-13    None             MSFT *<E0500QZLZX>  MSBILL.INFO     5.60
# 12 2024-02-12    None  LASTPASS.COM        BOSTON              MA  2925.10
# 13 2024-02-08    None  CALENDLY            AVONDALE ESTATES    GA   -51.84
# 14 2024-02-08    None  SERVER SUPPLY.COM INWESTBURY            NY   901.60
# 15 2024-02-07    None                     AMAZON MARKEPLACE NA PA    45.95
# 20           None     PLEASE REVIEW    AMAZON.COM       None
# 21         5114.0  00-0-005-0000-04       CHATGPT       None
# 22           None     PLEASE REVIEW    AMAZON.COM       None
# 23  Please Review     Please Review    CLOUDFLARE       None
# 24         5114.0  00-1-109-0000-01           NEW       None
# 25         5114.0  00-0-005-0000-04        SERVER       None
# 26         5113.0  00-0-005-0000-04         ADOBE       None
# 27         5113.0  00-0-005-0000-04         ADOBE       None
# 28         5113.0  00-0-005-0000-04         ADOBE       None
# 29         5130.0  00-0-005-0000-04        AMAZON       None
# 30         5035.0  00-0-005-0000-04       COMPTIA       None
# 31  Please Review  00-0-005-0000-04       COMCAST       None
# 32         5130.0  00-0-005-0000-04        AMAZON       None
# 33         5113.0  00-0-005-0000-04         ADOBE       None
# 34         5113.0  00-0-005-0000-04         ADOBE       None
# 35         5130.0  00-0-005-0000-04        AMAZON       None
# 36         5130.0  00-0-005-0000-04        AMAZON       None
# 37         5300.0  00-0-005-0000-04           CBT       None
#
#                                             File name     Column1
# 0       Comcast_Business_Internet_Invoice_1766273.pdf  Check Date
# 1                                                None        None
# 2                                                None        None
# 3                        Adobe Acrobat for Lauren.pdf        None
# 4             Amazon_ESTATA_Data_Cables_ChicagoDR.pdf        None
# 5                                                None        None
# 6                                                None        None
# 7                   Apple_MacBook_Pros_AAA1533249.pdf        None
# 8   MSFT Microsoft Defender for Office 365 (Plan 1...  Check Date
# 9   MSFT Project Plan 3 (Nonprofit Staff Pricing).pdf  Check Date
# 10   MSFT Office 365 E3 (Nonprofit Staff Pricing).pdf  Check Date
# 11  MSFT Project Online Essentials (Nonprofit Staf...  Check Date
# 12                       LastPass_Renewal_Receipt.pdf        None
# 13                                               None        None
# 14                          Server supply 4183063.pdf        None
# 15                            Amazon_Webcam_AnnaS.pdf        None
# 16                             Amazon_Webcam_Tony.pdf        None
# 17                       Amazon_Speakerphone_Anna.pdf        None
# 18                                               None        None
# 19                                               None        None
# 20           Amazon_Shipping_Materials_Chicago_DR.pdf        None
# 21                       ChatGPT_Business_Plan_IT.pdf        None
# 22                            Amazon_Monitor_Tony.pdf        None
# 23                                               None        None
# 24                   NewRelic_Invoice_INV00972418.pdf  Check Date
# 25        ServerCentral_Deft_transaction-IN136900.pdf        None
# 26                                               None        None
# 27                          Adobe for Stacy Bogle.pdf        None
# 28               Adobe Acrobat for Lauren Another.pdf        None
# 29                            Amazon_Batteries_IT.pdf        None
# 30                     CompTIA Server+ Bundle (1).pdf  Check Date
# 31                         Comcast_Business_Cable.pdf  Check Date
# 32            Amazon_Bluetooth_Speakers_IT_Events.pdf        None
# 33               Adobe Acrobat for Morgan Johnson.pdf        None
# 34                                               None        None
# 35  Amazon_Networking_2x_Cat6_Ethernet_Cables_Chic...  Check Date
# 36  1ft 2ft Cat6a cables - Amazon.com - Order 114-...  Check Date
# 37                                    CBT_Nuggets.pdf  Check Date
